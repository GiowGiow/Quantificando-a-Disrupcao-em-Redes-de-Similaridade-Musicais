# %% [markdown]
# # Computing distances with RBF Kernel

# %% [markdown]
# ### We load the dataset and cut it to make it computable. Visualizing in EDA it seems that they represent the complete dataset in somewhat representative way.
# ### Let's gets the first 20000 entries

# %%
# Loading dataset
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from pathlib import Path

# %% [markdown]
# # Loading dataframe

# %%
DATAFRAME_PATH = Path("./dataset")
DF_FILENAME = "song_info_release_dataset_29986_entries_filtered.csv"
dataframe = pd.read_csv(DATAFRAME_PATH / DF_FILENAME)
dataframe
# Out:
#                      id            artist                                song  \
# 0      0009fFIM1eYThaPg            Cheryl                          Rain on Me
# 1      0010xmHR6UICBOYT           Oddisee                      After Thoughts
# 2      002Jyd0vN4HyCpqL  Blue Öyster Cult                              ME 262
# 3      006TYKNjNxWjfKjy          Rhapsody                   Flames of Revenge
# 4      007LIJOPQ4Sb98qV    The Chameleons                           Nostalgia
# ...                 ...               ...                                 ...
# 29981  H1sPgVsyvDpq0Te6          Vulfpeck                               Outro
# 29982  H1sqqdwmIzskpKKy     Scar Symmetry                         The Anomaly
# 29983  H1tA6joyPNVBQ8JL               TRF                      BOY MEETS GIRL
# 29984  H1yNQyucqwOzKgpi      La casa azul  Los Chicos Hoy Saltarán A La Pista
# 29985  H1zMPV4MmgtIyGMH  The Black Angels             Bloodhounds On My Trail
#
#                                               album_name  \
# 0                                                3 Words
# 1                                      The Beauty in All
# 2                                        Secret Treaties
# 3                          Legendary Years (Re-Recorded)
# 4      What Does Anything Mean? Basically (2009 Remas...
# ...                                                  ...
# 29981                                          Vollmilch
# 29982                                  The Unseen Empire
# 29983                            WORKS -THE BEST OF TRF-
# 29984                            La Polinesia Meridional
# 29985                                           Passover
#
#                                                   genres  popularity  release  \
# 0                                                    pop        12.0     2009
# 1                                    underground hip hop        46.0     2013
# 2                            hard rock,rock,classic rock        31.0     1974
# 3      symphonic metal,power metal,symphonic power metal        33.0     2017
# 4                                     post-punk,new wave        19.0     2009
# ...                                                  ...         ...      ...
# 29981                                          funk,soul        42.0     2012
# 29982  melodic death metal,melodic death metal,progre...        36.0     2011
# 29983                                              j-pop        40.0     1998
# 29984      easy listening,soft rock,latin,pop,electropop        40.0     2011
# 29985                              psychedelic rock,rock        32.0     2006
#
#        duration_ms
# 0           229947
# 1           325096
# 2           285693
# 3           332867
# 4           326067
# ...            ...
# 29981       275849
# 29982       230887
# 29983       288560
# 29984       202972
# 29985       238693
#
# [29986 rows x 8 columns]

# %%
dataframe_sorted = dataframe.copy(deep=True)

# %%
# Fix wrong release data for some songs
dataframe_sorted['release'].replace(1013, 2013, inplace=True)

# Sort the dataset by date
dataframe_sorted = dataframe_sorted.sort_values(by=['release'])

dataframe_sorted
# Out:
#                      id           artist                        song  \
# 5987   3MEb9LZbB80nQ1a8  Louis Armstrong         St. James Infirmary
# 24349  DqO2fLBqdVsERa1Z  Louis Armstrong              Mack the Knife
# 2841   1Z7Pb158yANCZ7zN   Billie Holiday          Georgia On My Mind
# 822    0SI6oF0XlACvZdQT   Billie Holiday                   All Of Me
# 15583  8rCzU7kVpoJ0Z37D   Billie Holiday              A Fine Romance
# ...                 ...              ...                         ...
# 18420  ASqcyaIPBKyLiZPZ   Meghan Trainor                    Marry Me
# 9857   5YWnfGKCEtigHqqg            Talos                Far Out Dust
# 6636   3juSIghV4YtniyYj   Said the Whale                 Love Always
# 6673   3l5khhGHMUJ0ROPu  Salvador Sobral  Anda Estragar-me Os Planos
# 13808  7qGqmYBVXkzmRQ9L   Kakkmaddafakka                    MOON MAN
#
#                                               album_name  \
# 5987   The Complete Hot Five And Hot Seven Recordings...
# 24349                        The Great American Songbook
# 2841   Lady Day: The Complete Billie Holiday On Colum...
# 822    Lady Day: The Complete Billie Holiday On Colum...
# 15583  Lady Day: The Complete Billie Holiday On Colum...
# ...                                                  ...
# 18420                                     THE LOVE TRAIN
# 9857                                        Far Out Dust
# 6636                                            Cascadia
# 6673                                       Paris, Lisboa
# 13808                                          Diplomacy
#
#                                  genres  popularity  release  duration_ms
# 5987                         jazz,blues        29.0     1928       191867
# 24349       jazz,swing,jazz,blues,swing        43.0     1929       201467
# 2841              jazz,vocal jazz,blues        24.0     1933       198560
# 822    jazz,vocal jazz,blues,jazz,blues        54.0     1933       181440
# 15583                   jazz,jazz,blues        24.0     1933       171467
# ...                                 ...         ...      ...          ...
# 18420                     pop,soul,jazz        47.0     2019       215982
# 9857                            ambient        43.0     2019       282044
# 6636               indie rock,indie pop        26.0     2019       167707
# 6673               jazz,soul,eurovision        29.0     2019       166400
# 13808                   indie rock,rock        32.0     2019       214485
#
# [29986 rows x 8 columns]

# %%
# Loading Transfer Learning Features
transfer_learning_features = np.load("dataset/features.npy")
print("Shape: ", np.shape(transfer_learning_features))

# The transfer learning features have another ordenation, so we have to map our df to that
# Open list of files.txt
list_of_files = []
with open("dataset/list_of_files.txt", "r") as files_list:
    list_of_files = files_list.read().split(sep="\n")

print(list_of_files[:5])

# Get only the ids of the files so i can search by ID and get the row index
only_ids = []
for file_name in list_of_files:
    temp_path = Path(file_name)
    only_ids.append(temp_path.stem) # Gets only the filename without the extension .type

# Get every ID of our sorted dataframe
ids_sorted = dataframe_sorted["id"].to_numpy()

# Now i only need to create a list of indexes and add as a column
mapping_of_indexes = []

# Make the mapping of the indexes
for song_id in ids_sorted:
    mapping_of_indexes.append(only_ids.index(song_id))

# Adding as a column
dataframe_sorted["mapping_to_fv_index"] = mapping_of_indexes

# Reseting the index so that iloc works
df_sorted_reset_index = dataframe_sorted.reset_index()
df_sorted_reset_index
# Out:
# Shape:  (109269, 160)
# ['/home/giovanni-server/dev/college/TCC/dataset/music4all/audios/0YPssy4JykwvVcCR.mp3', '/home/giovanni-server/dev/college/TCC/dataset/music4all/audios/rkwibLwcBO99jzZL.mp3', '/home/giovanni-server/dev/college/TCC/dataset/music4all/audios/0ymAoxuOvi75xaY3.mp3', '/home/giovanni-server/dev/college/TCC/dataset/music4all/audios/0YMdOC9wMLrw2Wen.mp3', '/home/giovanni-server/dev/college/TCC/dataset/music4all/audios/RKwkKPcuPrqoJquj.mp3']
#        index                id           artist                        song  \
# 0       5987  3MEb9LZbB80nQ1a8  Louis Armstrong         St. James Infirmary
# 1      24349  DqO2fLBqdVsERa1Z  Louis Armstrong              Mack the Knife
# 2       2841  1Z7Pb158yANCZ7zN   Billie Holiday          Georgia On My Mind
# 3        822  0SI6oF0XlACvZdQT   Billie Holiday                   All Of Me
# 4      15583  8rCzU7kVpoJ0Z37D   Billie Holiday              A Fine Romance
# ...      ...               ...              ...                         ...
# 29981  18420  ASqcyaIPBKyLiZPZ   Meghan Trainor                    Marry Me
# 29982   9857  5YWnfGKCEtigHqqg            Talos                Far Out Dust
# 29983   6636  3juSIghV4YtniyYj   Said the Whale                 Love Always
# 29984   6673  3l5khhGHMUJ0ROPu  Salvador Sobral  Anda Estragar-me Os Planos
# 29985  13808  7qGqmYBVXkzmRQ9L   Kakkmaddafakka                    MOON MAN
#
#                                               album_name  \
# 0      The Complete Hot Five And Hot Seven Recordings...
# 1                            The Great American Songbook
# 2      Lady Day: The Complete Billie Holiday On Colum...
# 3      Lady Day: The Complete Billie Holiday On Colum...
# 4      Lady Day: The Complete Billie Holiday On Colum...
# ...                                                  ...
# 29981                                     THE LOVE TRAIN
# 29982                                       Far Out Dust
# 29983                                           Cascadia
# 29984                                      Paris, Lisboa
# 29985                                          Diplomacy
#
#                                  genres  popularity  release  duration_ms  \
# 0                            jazz,blues        29.0     1928       191867
# 1           jazz,swing,jazz,blues,swing        43.0     1929       201467
# 2                 jazz,vocal jazz,blues        24.0     1933       198560
# 3      jazz,vocal jazz,blues,jazz,blues        54.0     1933       181440
# 4                       jazz,jazz,blues        24.0     1933       171467
# ...                                 ...         ...      ...          ...
# 29981                     pop,soul,jazz        47.0     2019       215982
# 29982                           ambient        43.0     2019       282044
# 29983              indie rock,indie pop        26.0     2019       167707
# 29984              jazz,soul,eurovision        29.0     2019       166400
# 29985                   indie rock,rock        32.0     2019       214485
#
#        mapping_to_fv_index
# 0                    71045
# 1                    20950
# 2                    91346
# 3                    65996
# 4                   108063
# ...                    ...
# 29981                64357
# 29982               103866
# 29983                79436
# 29984                36509
# 29985                95536
#
# [29986 rows x 10 columns]

# %% [markdown]
# # Loading all features in a feature matrix

# %%
FEATURES_PATH = Path("../../dataset/dataset_mfcc")
FILE_ENDING = "_mfcc.npy"

def get_mfcc_feature_vector(df):
    """ Load and append the feature vector extracted to a variable """
    feature_vector = []
    ids_list = df['id'].to_list()
    for song_id in ids_list:
        file_name = song_id + FILE_ENDING
        file_path = FEATURES_PATH / file_name
        feature_vector.append(np.load(file_path).tolist())
    return feature_vector

mfcc_feature_vector = get_mfcc_feature_vector(dataframe_sorted)
print(np.shape(mfcc_feature_vector))
# Out:
# (29986, 120)

# %%
def get_transfer_learning_feature_vector(df, transfer_learning_feature_vector):
    feature_vector = []
    indexes_list = df['mapping_to_fv_index'].to_list()
    for index in indexes_list:
        feature_vector.append(transfer_learning_feature_vector[index])
    return feature_vector

transfer_learning_feature_vector = get_transfer_learning_feature_vector(df_sorted_reset_index, transfer_learning_features)
print(np.shape(transfer_learning_feature_vector))
# Out:
# (29986, 160)

# %% [markdown]
# # Export to avoid computations again

# %%
def export_feature_vector(feature_vector, name):
    """ Save computation next time! """
    size = np.shape(feature_vector)[0]
    np.save(f"{name}_feature_vector_{size}_samples.npy", feature_vector)
    print(f"Saving {name} feature_vector of {size} samples complete!")

export_feature_vector(transfer_learning_feature_vector, "transfer_learning")
export_feature_vector(mfcc_feature_vector, "mfcc")
# Out:
# Saving transfer_learning feature_vector of 29986 samples complete!
# Saving mfcc feature_vector of 29986 samples complete!

# %% [markdown]
# # Computing the similarity matrix using the RBF Kernel

# %%
from sklearn.metrics.pairwise import rbf_kernel

try: # Try to free memory when running for a second time
    del similarity_matrix
    import gc
    gc.collect()
except NameError:
    pass

gamma = 0.1
similarity_matrix = rbf_kernel(transfer_learning_feature_vector, gamma=gamma)
np.fill_diagonal(similarity_matrix, 0)

# %%
def save_similarity_matrix(gamma, matrix):
    size = np.shape(matrix)[0]
    np.save(f"similarity_matrix_{size}_samples_gamma_{gamma}.npy", matrix)
    print(f"Saving similarity matrix of size {size} complete!")

save_similarity_matrix(gamma, similarity_matrix)
# Out:
# Saving similarity matrix of size 29986 complete!

# %%
# Just checking how many relevant similarities we get
rows, _ = np.where(similarity_matrix > 0.6)
len(rows)
# Out:
# 587025378

# %% [markdown]
# # Helper functions to help analyze/filter the dataset

# %%
from math import ceil

def show_similarity(df, similarity_matrix, song_index, song_two_index):
    """ Shows the similarity of two entries of a similarity matrix """
    print()
    print(df.iloc[song_index])
    print(df.iloc[song_two_index])
    print()
    similarity = similarity_matrix[song_index, song_two_index]
    print(f"Similarity: {similarity}")
    
def get_songs_list(df, similarity_matrix, similarity_threshold, limit=10):
    """ Get the list of song similarities for a similarity threshold """
    rows, columns = np.where(similarity_matrix > similarity_threshold)
    print(len(similarity_matrix[rows, columns]))
    songs_list = np.array((rows, columns)).T
    songs_list = songs_list[:ceil(len(songs_list)/2)]
    for song in songs_list[:limit]:
        show_similarity(df, similarity_matrix, song[0], song[1])

def find_empty_songs_export_dataset(df, similarity_matrix):
    """ Function to remove and export the dataset without the empty songs
        needs to be ran after the similarity matrix has been computed """
    def get_df_size(df):
        return np.shape(df)[0]
        
    def find_madonna_song_index(df):
        """ Finds a song that we know that doesn't have audio """
        return df.query("song == 'Candy Shop Medley (Live)'").index
    
    madonna_song_index = find_madonna_song_index(df)
    # the [0] its because it is a 2d array containing only 1 list
    madonna_row = similarity_matrix[madonna_song_index][0] 
    empty_samples_to_exclude_list = np.where(madonna_row > 0.9)[0]
    np.append(empty_samples_to_exclude_list, madonna_song_index)

    print(f"There are {len(empty_samples_to_exclude_list)} empty songs")

    # find their ids
    empty_samples_to_exclude_list_ids = df['id'][empty_samples_to_exclude_list].to_list()
    
    print("Removing empty songs from dataset")
    df = df[~df['id'].isin(empty_samples_to_exclude_list_ids)]
    
    print(f"Exporting dataset of size {get_df_size(df)}")
    df.to_csv(f"song_info_dataset_{get_df_size(df)}_entries_filtered.csv", index=False)

# %% [markdown]
# # Exporting the dataset filtered

# %%
find_empty_songs_export_dataset(dataframe_sorted, similarity_matrix)
# Out:
# There are 0 empty songs
# Removing empty songs from dataset
# Exporting dataset of size 29986

# %%
import sys
import gc

def sizeof_fmt(num, suffix='B'):
    ''' by Fred Cirera,  https://stackoverflow.com/a/1094933/1870254, modified'''
    for unit in ['','Ki','Mi','Gi','Ti','Pi','Ei','Zi']:
        if abs(num) < 1024.0:
            return "%3.1f %s%s" % (num, unit, suffix)
        num /= 1024.0
    return "%.1f %s%s" % (num, 'Yi', suffix)

for name, size in sorted(((name, sys.getsizeof(value)) for name, value in locals().items()),
                            key= lambda x: -x[1])[:10]:
    print("{:>30}: {:>8}".format(name, sizeof_fmt(size)))

#del similarity_matrix
gc.collect()
# Out:
#              similarity_matrix:  3.3 GiB
#     transfer_learning_features: 66.7 MiB
#                             __: 11.7 MiB
#          df_sorted_reset_index: 11.7 MiB
#                            _10: 11.7 MiB
#                            ___: 11.7 MiB
#               dataframe_sorted: 11.7 MiB
#                             _9: 11.7 MiB
#                      dataframe: 11.2 MiB
#                             _7: 11.2 MiB
# 0

# %% [markdown]
# # Showing some songs with high similarity
#
# ### When using gamma = 0.01, only masters and remasters of the same songs show as similar

# %%
get_songs_list(dataframe, similarity_matrix, 0.8)
# Out:
# 140
#
# id                                             06SC55N0G2GjCNuS
# artist                                              David Bowie
# song                                         Station to Station
# album_name         Station To Station (2016 Remastered Version)
# genres        rock,progressive rock,classic rock,art rock,ro...
# Name: 159, dtype: object
# id                                        7JmWTjyaKLzHmKBo
# artist                                         David Bowie
# song          Station To Station (2016 Remastered Version)
# album_name    Station To Station (2016 Remastered Version)
# genres                         glam rock,rock,classic rock
# Name: 12886, dtype: object
#
# Similarity: 0.9999999999995635
#
# id                    0EvGCDSvdzIZdcQ3
# artist                      Kid Abelha
# song                      Peito Aberto
# album_name                   Pega Vida
# genres        mpb,pop nacional,mpb,pop
# Name: 403, dtype: object
# id            6xboh6SVR8Z0qHXj
# artist              Kid Abelha
# song             Fala Meu Nome
# album_name           Pega Vida
# genres                 mpb,pop
# Name: 12248, dtype: object
#
# Similarity: 1.0
#
# id                                             0MPG1YPEzBIOsEFR
# artist                                 Electric Light Orchestra
# song                                                   Eldorado
# album_name                                             Eldorado
# genres        rock,classic rock,pop,progressive rock,symphon...
# Name: 632, dtype: object
# id                                  49bdTCRf7vvkxqZl
# artist                      Electric Light Orchestra
# song                     Can't Get It Out of My Head
# album_name                                  Eldorado
# genres        classic rock,rock,progressive rock,pop
# Name: 7403, dtype: object
#
# Similarity: 1.0
#
# id                            0PmpqNaTqNzRV19t
# artist                              Little Mix
# song                         No More Sad Songs
# album_name    Glory Days: The Platinum Edition
# genres                                     pop
# Name: 735, dtype: object
# id                                3CBvKFEF9qkGR7sg
# artist                                  Little Mix
# song          No More Sad Songs - Acoustic Version
# album_name        Glory Days: The Platinum Edition
# genres                                     pop,pop
# Name: 5698, dtype: object
#
# Similarity: 1.0
#
# id                       0YG71J60HAJ5Glxd
# artist                                UFO
# song                        Doctor Doctor
# album_name     Phenomenon (2007 Remaster)
# genres        hard rock,classic rock,rock
# Name: 1000, dtype: object
# id                         1H7yQe1NljCbMapi
# artist                                  UFO
# song          Doctor Doctor - 2007 Remaster
# album_name       Phenomenon (2007 Remaster)
# genres                       hard rock,rock
# Name: 2317, dtype: object
#
# Similarity: 0.9945247144500841
#
# id                            0eYMyFT6MQ11hm68
# artist                              Little Mix
# song                          Touch - Acoustic
# album_name    Glory Days: The Platinum Edition
# genres                                     pop
# Name: 1185, dtype: object
# id                            B2D76p4YqZPLEImB
# artist                              Little Mix
# song                                     Touch
# album_name    Glory Days: The Platinum Edition
# genres                                     pop
# Name: 19433, dtype: object
#
# Similarity: 0.9999999999998544
#
# id                                             0nTJwKgAotSVunDM
# artist                                    The Smashing Pumpkins
# song                                     Siva - Remastered 2011
# album_name                                Gish (Deluxe Edition)
# genres        alternative rock,grunge,rock,alternative rock,...
# Name: 1436, dtype: object
# id                        7SKAFUzD5tVo4yAi
# artist               The Smashing Pumpkins
# song                                  Siva
# album_name           Gish (Deluxe Edition)
# genres        alternative rock,rock,grunge
# Name: 13136, dtype: object
#
# Similarity: 0.9999999999982537
#
# id                        0vAvl1yw6ePzypaY
# artist                        All Time Low
# song                     Life of the Party
# album_name             Last Young Renegade
# genres        pop rock,rock,pop,electropop
# Name: 1656, dtype: object
# id                                       5uAjesvDt7mRJCqO
# artist                                       All Time Low
# song                               Dark Side of Your Room
# album_name                            Last Young Renegade
# genres        pop punk,pop rock,alternative rock,rock,pop
# Name: 10491, dtype: object
#
# Similarity: 0.9999999999999636
#
# id                       0zmrxUHKXRslsrVe
# artist                        Sonic Youth
# song                           Star Power
# album_name    Star Power (2009; Acoustic)
# genres          post-punk,noise rock,rock
# Name: 1784, dtype: object
# id                       6zvBm3jtkQZuGEOh
# artist                        Sonic Youth
# song                            Starpower
# album_name                           Evol
# genres        alternative rock,noise rock
# Name: 12311, dtype: object
#
# Similarity: 0.9999999999991269
#
# id                  1DxHjPS6xQpp5vqz
# artist                          Mika
# song                       Good Wife
# album_name        No Place In Heaven
# genres        pop,britpop,electronic
# Name: 2227, dtype: object
# id             5WKOH9Bg4jHrbptT
# artist               Tori Kelly
# song          Should've Been Us
# album_name    Unbreakable Smile
# genres                      pop
# Name: 9800, dtype: object
#
# Similarity: 0.962793000717607

# %% [markdown]
# # Showing the same information but for the beatles

# %%
beatles_df = dataframe.query("artist == 'The Beatles'")
print(len(beatles_df))
beatles_feature_vector = get_feature_vector(beatles_df)
beatles_similarity_matrix = rbf_kernel(beatles_feature_vector, gamma=0.001)
np.fill_diagonal(beatles_similarity_matrix, 0)
get_songs_list(beatles_df, beatles_similarity_matrix, 0.7)
# Out:
# 37
# 2
#
# id                                      6NRxkIqKybHZZGvZ
# artist                                       The Beatles
# song          Why Don't We Do It In The Road? - 2018 Mix
# album_name                                   The Beatles
# genres                             classic rock,rock,pop
# Name: 11252, dtype: object
# id                                             BD1AtNm4DiD3tjQ0
# artist                                              The Beatles
# song          Why Don't We Do It In The Road? - Remastered 2009
# album_name                             The Beatles (Remastered)
# genres                   rock,classic rock,pop,psychedelic rock
# Name: 19734, dtype: object
#
# Similarity: 1.0

# %%
np.shape(similarity_matrix)
# Out:
# (19995, 19995)

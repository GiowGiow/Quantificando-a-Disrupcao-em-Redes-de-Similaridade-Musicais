# %% [markdown]
# # Loading datasets into Dataframes
#
# The first step is to always load the dataframes we have

# %% [markdown]
# Making necessary imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

# %% [markdown]
# Loading the necessary dataframes

# %%
# Dataset paths
dataset_name = "music4all"
dataset_relative_location = "../../../dataset"
dataset_path = Path(dataset_relative_location) / dataset_name

# Get all CSVs in folder
csvsPattern = "*.csv"
csvs = list(dataset_path.glob(csvsPattern))
csvs

datasets = {}
# Load each one into a dataframe
for csv in csvs:
    datasets[csv.stem] = pd.read_csv(csv, delimiter="\t")

# %% [markdown]
# After loading all the .csvs provided by the Music4All dataset we can start working with them, as each contains some information about the songs in them.
#
# Let's a look at the datasets we have:

# %%
datasets.keys()
# Out:
# dict_keys(['id_tags', 'id_metadata', 'id_information', 'listening_history', 'id_lang', 'id_genres'])

# %% [markdown]
# ### Merging the datasets together can provide a lot of meaningful information

# %%
song_info = pd.merge(datasets['id_information'], datasets['id_genres'], on='id')
song_info = pd.merge(song_info, datasets['id_metadata'], on='id') # has release date info
song_info.head()
# Out:
#                  id            artist               song  \
# 0  0009fFIM1eYThaPg            Cheryl         Rain on Me
# 1  0010xmHR6UICBOYT           Oddisee     After Thoughts
# 2  002Jyd0vN4HyCpqL  Blue Öyster Cult             ME 262
# 3  006TYKNjNxWjfKjy          Rhapsody  Flames of Revenge
# 4  007LIJOPQ4Sb98qV    The Chameleons          Nostalgia
#
#                                           album_name  \
# 0                                            3 Words
# 1                                  The Beauty in All
# 2                                    Secret Treaties
# 3                      Legendary Years (Re-Recorded)
# 4  What Does Anything Mean? Basically (2009 Remas...
#
#                                               genres              spotify_id  \
# 0                                                pop  3eObKIfHKJ1nAPh0wTxFCc
# 1                                underground hip hop  27szvF97Tu95GxN98N52fy
# 2                        hard rock,rock,classic rock  273lBFpxUCwisTpdnF9cVb
# 3  symphonic metal,power metal,symphonic power metal  1qZgergQ41vaD4zBf3AKXR
# 4                                 post-punk,new wave  6rVxJ3sN3Cz40MSLavbG1K
#
#    popularity  release  danceability  energy  key  mode  valence    tempo  \
# 0        12.0     2009         0.635   0.746  6.0   1.0    0.548  110.973
# 1        46.0     2013         0.591   0.513  7.0   0.0    0.263  172.208
# 2        31.0     1974         0.319   0.925  2.0   1.0    0.658  157.630
# 3        33.0     2017         0.432   0.979  7.0   1.0    0.162   90.008
# 4        19.0     2009         0.357   0.708  9.0   1.0    0.470  123.904
#
#    duration_ms
# 0       229947
# 1       325096
# 2       285693
# 3       332867
# 4       326067

# %% [markdown]
# Let's check if there is any weird value in it

# %%
song_info.describe()
# Out:
#           popularity        release   danceability         energy  \
# count  109269.000000  109269.000000  109269.000000  109269.000000
# mean       35.080608    2005.813488       0.520449       0.667162
# std        14.756258      14.335056       0.173008       0.241372
# min         0.000000    1013.000000       0.000000       0.000000
# 25%        25.000000    2001.000000       0.403000       0.502000
# 50%        34.000000    2011.000000       0.528000       0.712000
# 75%        45.000000    2016.000000       0.645000       0.872000
# max        95.000000    2019.000000       0.988000       1.000000
#
#                  key           mode        valence          tempo  \
# count  109269.000000  109269.000000  109269.000000  109269.000000
# mean        5.284079       0.624669       0.445504     122.753032
# std         3.560797       0.484210       0.252159      28.997936
# min         0.000000       0.000000       0.000000       0.000000
# 25%         2.000000       0.000000       0.236000     100.194000
# 50%         5.000000       1.000000       0.424000     121.079000
# 75%         9.000000       1.000000       0.639000     140.047000
# max        11.000000       1.000000       0.998000     242.903000
#
#         duration_ms
# count  1.092690e+05
# mean   2.425046e+05
# std    1.003360e+05
# min    7.229000e+03
# 25%    1.934810e+05
# 50%    2.275330e+05
# 75%    2.715330e+05
# max    4.995315e+06

# %% [markdown]
# The amount of songs seems to match, but wait, the oldest song in the dataset is not from "1013", actually all songs with release date <= 1900 have the wrong release date

# %%
song_info.query("release <= 1900")
# Out:
#                      id         artist                         song  \
# 10350  5pClePd8cdUOGQe2  Los Espíritus           Lo Echaron del Bar
# 13762  7oBqYSOUt2PehcJd  Los Espíritus          Jesús rima con cruz
# 62143  ZEuwJ4wJH5GW6ay9    Bukka White          Parchman Farm Blues
# 83323  lHUghlsxSApSGZ4i   Sidney Polak  Otwieram Wino - feat. Pezet
# 83679  lUJHN9keOtaNGCYK  Los Espíritus             noches de verano
#
#            album_name                                             genres  \
# 10350   Los Espíritus  latin,rock,psychedelic rock,latin,rock,psyched...
# 13762   Los Espíritus  latin,rock,psychedelic rock,latin,rock,psyched...
# 62143  Good Gin Blues                                  blues,delta blues
# 83323      (Untitled)                                  reggae,rap,reggae
# 83679   Los Espíritus                        latin,rock,psychedelic rock
#
#                    spotify_id  popularity  release  danceability  energy  key  \
# 10350  45LCjFwH5veyV1twkPFKVO        35.0     1013         0.595   0.761  7.0
# 13762  0ytnXiwu42kNYnBvS48nc5        27.0     1013         0.443   0.688  7.0
# 62143  09sKCJcVUC24vgpaamdkrj        30.0     1899         0.548   0.335  9.0
# 83323  39Cw7Nac50scksR3vMREQy         3.0     1900         0.721   0.737  8.0
# 83679  5sFEbn2q1dI0xO06BKkcH1        40.0     1013         0.639   0.512  8.0
#
#        mode  valence    tempo  duration_ms
# 10350   0.0    0.868  166.503       268507
# 13762   1.0    0.717   95.729       296680
# 62143   0.0    0.656   98.688       162067
# 83323   1.0    0.878   99.091       238573
# 83679   0.0    0.598  127.451       299880

# %%
# Fix wrong release data for some songs

# Los Espiritus album was released in 2013
song_info['release'].replace(1013, 2013, inplace=True)

# Bukka White - Parchman Farm Blues was released in 1940
song_info['release'].replace(1899, 1940, inplace=True)

# Sidney Polak	Otwieram Wino - feat. Pezet according to amazon was released in 2018
song_info['release'].replace(1900, 2018, inplace=True)

# %% [markdown]
# ## Removing empty MP3 Songs

# %% [markdown]
# The details of how they are identified are in identifying_empty_songs.py script

# %%
# Loading empty songs list 
with open("empty_mp3_ids.txt", "r") as file:
    empty_songs = list(file.read().split("\n"))

cleaned_song_info = song_info[~song_info.id.isin(empty_songs)]

# %%
print(len(song_info))
print(len(cleaned_song_info))
# Out:
# 109269
# 109178

# %% [markdown]
# ## We can now export the cleaned dataset

# %% [markdown]
# We will often use a partitioned dataset for computational reasons the dataset is too big to work with

# %%
df_sizes_to_work_with = [20000, 30000]
for size in df_sizes_to_work_with:
    partitioned_df = cleaned_song_info[:size]
    partitioned_df.to_csv(f"../dataset/cleaned_datasets/cleaned_song_info_cleaned_{len(partitioned_df)}_entries.csv")    

cleaned_song_info.to_csv(f"../dataset/cleaned_datasets/cleaned_song_info_cleaned_{len(cleaned_song_info)}_entries.csv")
